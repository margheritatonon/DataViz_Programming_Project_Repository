# %%
#you want to separate all of the tasks into different scripts.
#but all the classes are interconnected
#so you need to import the class 
#from dataviz_programming_project_repository import thenameofyourotherfile
